# %% [markdown]
# ![XKCD data pipeline](https://imgs.xkcd.com/comics/data_pipeline.png)
#
# [https://xkcd.com/2054](https://xkcd.com/2054/)

# %% [markdown]
# 1. http://www.nhc.noaa.gov/gis/
# 2. https://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/
#
# https://www.nhc.noaa.gov/gis/archive_besttrack.php?year=2018
#
# NHC codes storms are coded with 8 letter names:
# - 2 char for region `al` &rarr; Atlantic
# - 2 char for number `11` is Irma
# - and 4 char for year, `2017`
#
# Browse http://www.nhc.noaa.gov/gis/archive_wsurge.php?year=2017 to find other hurricanes code.

# %%
import os

import geopandas

import wget


def load_best_track(code='al14', year='2018'):
    fname = f'{code}{year}_best_track.zip'
    url = f'https://www.nhc.noaa.gov/gis/best_track/{fname}'

    if not os.path.isfile(fname):
        import wget
        fname = wget.download(url)

    os.environ['CPL_ZIP_ENCODING'] = 'UTF-8'

    radii = geopandas.read_file(
        f'/{code.upper()}{year}_radii.shp',
        vfs='zip://{}'.format(fname)
    )

    pts = geopandas.read_file(
        f'/{code.upper()}{year}_pts.shp',
        vfs='zip://{}'.format(fname)
    )
    return radii, pts


radii, pts = load_best_track(code='al14', year='2018')
bbox = tuple(radii['geometry'].total_bounds)

# %%
pts.columns
# Out:
# Index(['STORMNAME', 'DTG', 'YEAR', 'MONTH', 'DAY', 'HHMM', 'MSLP', 'BASIN',
#        'STORMNUM', 'STORMTYPE', 'INTENSITY', 'SS', 'LAT', 'LON', 'geometry'],
#       dtype='object')

# %%
import shapely


coords = zip(pts['LON'], pts['LAT'])
track = shapely.geometry.LineString(coords)

# %% [markdown]
# Now we can get all the information we need from those GIS files. Let's start with the event dates.

# %%
import pandas as pd


pts['str'] = pts['DTG'].astype(int).astype(str)

pts.index = pd.to_datetime(
    pts['str'], format='%Y%m%d%H', errors='coerce').values

# %%
start = pts.index[0]
end = pts.index[-1]

# %% [markdown]
# And the bounding box to search the data.

# %%
strbbox = ', '.join(format(v, '.2f') for v in bbox)
print('bbox: {}\nstart: {}\n  end: {}'.format(strbbox, start, end))
# Out:
# bbox: -89.23, 15.71, -69.99, 38.80
# start: 2018-10-07 06:00:00
#   end: 2018-10-12 06:00:00

# %% [markdown]
# Now we need to build a filter with those parameters to find the observations along the Hurricane path. We still need to specify:
#
# - the units for the observations;
# - and the SOS name for the variables of interest.
#
# Next, we can use `pyoos` to assemble a collector to download the data into a pandas `DataFrame`.

# %%
import cf_units
from ioos_tools.ioos import collector2table
import pandas as pd
from pyoos.collectors.coops.coops_sos import CoopsSos
from retrying import retry


# We need to retry in case of failure b/c the server cannot handle
# the high traffic during events like Irma.
@retry(stop_max_attempt_number=5, wait_fixed=3000)
def get_coops(start, end, sos_name, units, bbox, verbose=False):
    collector = CoopsSos()
    collector.set_bbox(bbox)
    collector.end_time = end
    collector.start_time = start
    collector.variables = [sos_name]
    ofrs = collector.server.offerings
    title = collector.server.identification.title
    config = dict(
        units=units,
        sos_name=sos_name,
    )

    data = collector2table(
        collector=collector,
        config=config,
        col='{} ({})'.format(sos_name, units.format(cf_units.UT_ISO_8859_1))
    )

    # Clean the table.
    table = dict(
        station_name=[s._metadata.get('station_name') for s in data],
        station_code=[s._metadata.get('station_code') for s in data],
        sensor=[s._metadata.get('sensor') for s in data],
        lon=[s._metadata.get('lon') for s in data],
        lat=[s._metadata.get('lat') for s in data],
        depth=[s._metadata.get('depth', 'NA') for s in data],
    )

    table = pd.DataFrame(table).set_index('station_name')
    if verbose:
        print('Collector offerings')
        print('{}: {} offerings'.format(title, len(ofrs)))
    return data, table

# %%
ssh, ssh_table = get_coops(
    start=start,
    end=end,
    sos_name='water_surface_height_above_reference_datum',
    units=cf_units.Unit('meters'),
    bbox=bbox,
)

ssh_table
# Out:
#                                         station_code  \
# station_name
# Lewes, DE                                    8557380
# Ocean City Inlet, MD                         8570283
# Bishops Head, MD                             8571421
# Cambridge, MD                                8571892
# Solomons Island, MD                          8577330
# Wachapreague, VA                             8631044
# Kiptopeke, VA                                8632200
# Dahlgren, VA                                 8635027
# Lewisetta, VA                                8635750
# Windmill Point, VA                           8636580
# Yorktown USCG Training Center, VA            8637689
# Sewells Point, VA                            8638610
# CBBT, Chesapeake Channel, VA                 8638901
# Money Point, VA                              8639348
# Duck, NC                                     8651370
# Oregon Inlet Marina, NC                      8652587
# USCG Station Hatteras, NC                    8654467
# Beaufort, Duke Marine Lab, NC                8656483
# Wilmington, NC                               8658120
# Wrightsville Beach, NC                       8658163
# Springmaid Pier, SC                          8661070
# Oyster Landing (N Inlet Estuary), SC         8662245
# Charleston, Cooper River Entrance, SC        8665530
# Fort Pulaski, GA                             8670870
# Fernandina Beach, FL                         8720030
# Mayport (Bar Pilots Dock), FL                8720218
# Dames Point, FL                              8720219
# Southbank Riverwalk, St Johns River, FL      8720226
# Racy Point, St Johns River, FL               8720625
# Trident Pier, Port Canaveral, FL             8721604
# Lake Worth Pier, Atlantic Ocean, FL          8722670
# South Port Everglades, FL                    8722956
# Virginia Key, Biscayne Bay, FL               8723214
# Vaca Key, Florida Bay, FL                    8723970
# Key West, FL                                 8724580
# Naples, Gulf of Mexico, FL                   8725110
# Fort Myers, Caloosahatchee River, FL         8725520
# Port Manatee, FL                             8726384
# St. Petersburg, Tampa Bay, FL                8726520
# Old Port Tampa, FL                           8726607
# Mckay Bay Entrance, FL                       8726667
# Clearwater Beach, FL                         8726724
# Cedar Key, FL                                8727520
# Apalachicola, FL                             8728690
# Panama City, FL                              8729108
# Panama City Beach, FL                        8729210
# Pensacola, FL                                8729840
# Weeks Bay, Mobile Bay, AL                    8732828
# Dauphin Island, AL                           8735180
# Dog River Bridge, AL                         8735391
# East Fowl River Bridge, AL                   8735523
# Coast Guard Sector Mobile, AL                8736897
# Mobile State Docks, AL                       8737048
# Chickasaw Creek, AL                          8737138
# West Fowl River Bridge, AL                   8738043
# Bayou La Batre Bridge, AL                    8739803
# Grand Bay NERR, Mississippi Sound, MS        8740166
# Pascagoula NOAA Lab, MS                      8741533
#
#                                                                              sensor  \
# station_name
# Lewes, DE                                urn:ioos:sensor:NOAA.NOS.CO-OPS:8557380:A1
# Ocean City Inlet, MD                     urn:ioos:sensor:NOAA.NOS.CO-OPS:8570283:A1
# Bishops Head, MD                         urn:ioos:sensor:NOAA.NOS.CO-OPS:8571421:A1
# Cambridge, MD                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8571892:Y1
# Solomons Island, MD                      urn:ioos:sensor:NOAA.NOS.CO-OPS:8577330:Y1
# Wachapreague, VA                         urn:ioos:sensor:NOAA.NOS.CO-OPS:8631044:Y1
# Kiptopeke, VA                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8632200:A1
# Dahlgren, VA                             urn:ioos:sensor:NOAA.NOS.CO-OPS:8635027:Y1
# Lewisetta, VA                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8635750:A1
# Windmill Point, VA                       urn:ioos:sensor:NOAA.NOS.CO-OPS:8636580:Y1
# Yorktown USCG Training Center, VA        urn:ioos:sensor:NOAA.NOS.CO-OPS:8637689:A1
# Sewells Point, VA                        urn:ioos:sensor:NOAA.NOS.CO-OPS:8638610:A1
# CBBT, Chesapeake Channel, VA             urn:ioos:sensor:NOAA.NOS.CO-OPS:8638901:Y1
# Money Point, VA                          urn:ioos:sensor:NOAA.NOS.CO-OPS:8639348:Y1
# Duck, NC                                 urn:ioos:sensor:NOAA.NOS.CO-OPS:8651370:A1
# Oregon Inlet Marina, NC                  urn:ioos:sensor:NOAA.NOS.CO-OPS:8652587:A1
# USCG Station Hatteras, NC                urn:ioos:sensor:NOAA.NOS.CO-OPS:8654467:A1
# Beaufort, Duke Marine Lab, NC            urn:ioos:sensor:NOAA.NOS.CO-OPS:8656483:A1
# Wilmington, NC                           urn:ioos:sensor:NOAA.NOS.CO-OPS:8658120:A1
# Wrightsville Beach, NC                   urn:ioos:sensor:NOAA.NOS.CO-OPS:8658163:A1
# Springmaid Pier, SC                      urn:ioos:sensor:NOAA.NOS.CO-OPS:8661070:Y1
# Oyster Landing (N Inlet Estuary), SC     urn:ioos:sensor:NOAA.NOS.CO-OPS:8662245:A1
# Charleston, Cooper River Entrance, SC    urn:ioos:sensor:NOAA.NOS.CO-OPS:8665530:A1
# Fort Pulaski, GA                         urn:ioos:sensor:NOAA.NOS.CO-OPS:8670870:A1
# Fernandina Beach, FL                     urn:ioos:sensor:NOAA.NOS.CO-OPS:8720030:Y1
# Mayport (Bar Pilots Dock), FL            urn:ioos:sensor:NOAA.NOS.CO-OPS:8720218:A1
# Dames Point, FL                          urn:ioos:sensor:NOAA.NOS.CO-OPS:8720219:A1
# Southbank Riverwalk, St Johns River, FL  urn:ioos:sensor:NOAA.NOS.CO-OPS:8720226:Y1
# Racy Point, St Johns River, FL           urn:ioos:sensor:NOAA.NOS.CO-OPS:8720625:A1
# Trident Pier, Port Canaveral, FL         urn:ioos:sensor:NOAA.NOS.CO-OPS:8721604:Y1
# Lake Worth Pier, Atlantic Ocean, FL      urn:ioos:sensor:NOAA.NOS.CO-OPS:8722670:A1
# South Port Everglades, FL                urn:ioos:sensor:NOAA.NOS.CO-OPS:8722956:Y1
# Virginia Key, Biscayne Bay, FL           urn:ioos:sensor:NOAA.NOS.CO-OPS:8723214:A1
# Vaca Key, Florida Bay, FL                urn:ioos:sensor:NOAA.NOS.CO-OPS:8723970:A1
# Key West, FL                             urn:ioos:sensor:NOAA.NOS.CO-OPS:8724580:Y1
# Naples, Gulf of Mexico, FL               urn:ioos:sensor:NOAA.NOS.CO-OPS:8725110:A1
# Fort Myers, Caloosahatchee River, FL     urn:ioos:sensor:NOAA.NOS.CO-OPS:8725520:Y1
# Port Manatee, FL                         urn:ioos:sensor:NOAA.NOS.CO-OPS:8726384:A1
# St. Petersburg, Tampa Bay, FL            urn:ioos:sensor:NOAA.NOS.CO-OPS:8726520:Y1
# Old Port Tampa, FL                       urn:ioos:sensor:NOAA.NOS.CO-OPS:8726607:A1
# Mckay Bay Entrance, FL                   urn:ioos:sensor:NOAA.NOS.CO-OPS:8726667:A1
# Clearwater Beach, FL                     urn:ioos:sensor:NOAA.NOS.CO-OPS:8726724:A1
# Cedar Key, FL                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8727520:A1
# Apalachicola, FL                         urn:ioos:sensor:NOAA.NOS.CO-OPS:8728690:A1
# Panama City, FL                          urn:ioos:sensor:NOAA.NOS.CO-OPS:8729108:A1
# Panama City Beach, FL                    urn:ioos:sensor:NOAA.NOS.CO-OPS:8729210:A1
# Pensacola, FL                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8729840:A1
# Weeks Bay, Mobile Bay, AL                urn:ioos:sensor:NOAA.NOS.CO-OPS:8732828:A1
# Dauphin Island, AL                       urn:ioos:sensor:NOAA.NOS.CO-OPS:8735180:A1
# Dog River Bridge, AL                     urn:ioos:sensor:NOAA.NOS.CO-OPS:8735391:Y1
# East Fowl River Bridge, AL               urn:ioos:sensor:NOAA.NOS.CO-OPS:8735523:Y1
# Coast Guard Sector Mobile, AL            urn:ioos:sensor:NOAA.NOS.CO-OPS:8736897:A1
# Mobile State Docks, AL                   urn:ioos:sensor:NOAA.NOS.CO-OPS:8737048:A1
# Chickasaw Creek, AL                      urn:ioos:sensor:NOAA.NOS.CO-OPS:8737138:Y1
# West Fowl River Bridge, AL               urn:ioos:sensor:NOAA.NOS.CO-OPS:8738043:Y1
# Bayou La Batre Bridge, AL                urn:ioos:sensor:NOAA.NOS.CO-OPS:8739803:Y1
# Grand Bay NERR, Mississippi Sound, MS    urn:ioos:sensor:NOAA.NOS.CO-OPS:8740166:A1
# Pascagoula NOAA Lab, MS                  urn:ioos:sensor:NOAA.NOS.CO-OPS:8741533:A1
#
#                                              lon      lat depth
# station_name
# Lewes, DE                               -75.1192  38.7828  None
# Ocean City Inlet, MD                    -75.0911  38.3283  None
# Bishops Head, MD                        -76.0387  38.2204  None
# Cambridge, MD                           -76.0722  38.5742  None
# Solomons Island, MD                     -76.4508  38.3172  None
# Wachapreague, VA                        -75.6858  37.6078  None
# Kiptopeke, VA                           -75.9884  37.1652  None
# Dahlgren, VA                            -77.0366  38.3197  None
# Lewisetta, VA                           -76.4646  37.9954  None
# Windmill Point, VA                      -76.2900  37.6161  None
# Yorktown USCG Training Center, VA       -76.4788  37.2265  None
# Sewells Point, VA                       -76.3300  36.9467  None
# CBBT, Chesapeake Channel, VA            -76.0833  37.0329  None
# Money Point, VA                         -76.3017  36.7783  None
# Duck, NC                                -75.7467  36.1833  None
# Oregon Inlet Marina, NC                 -75.5481  35.7950  None
# USCG Station Hatteras, NC               -75.7042  35.2086  None
# Beaufort, Duke Marine Lab, NC           -76.6700  34.7200  None
# Wilmington, NC                          -77.9536  34.2275  None
# Wrightsville Beach, NC                  -77.7867  34.2133  None
# Springmaid Pier, SC                     -78.9183  33.6550  None
# Oyster Landing (N Inlet Estuary), SC    -79.1867  33.3517  None
# Charleston, Cooper River Entrance, SC   -79.9236  32.7808  None
# Fort Pulaski, GA                        -80.9017  32.0367  None
# Fernandina Beach, FL                    -81.4658  30.6714  None
# Mayport (Bar Pilots Dock), FL           -81.4279  30.3982  None
# Dames Point, FL                         -81.5592  30.3872  None
# Southbank Riverwalk, St Johns River, FL -81.6591  30.3205  None
# Racy Point, St Johns River, FL          -81.5498  29.8002  None
# Trident Pier, Port Canaveral, FL        -80.5931  28.4158  None
# Lake Worth Pier, Atlantic Ocean, FL     -80.0342  26.6128  None
# South Port Everglades, FL               -80.1167  26.0817  None
# Virginia Key, Biscayne Bay, FL          -80.1617  25.7317  None
# Vaca Key, Florida Bay, FL               -81.1065  24.7110  None
# Key West, FL                            -81.8078  24.5558  None
# Naples, Gulf of Mexico, FL              -81.8075  26.1317  None
# Fort Myers, Caloosahatchee River, FL    -81.8710  26.6480  None
# Port Manatee, FL                        -82.5625  27.6383  None
# St. Petersburg, Tampa Bay, FL           -82.6269  27.7606  None
# Old Port Tampa, FL                      -82.5528  27.8578  None
# Mckay Bay Entrance, FL                  -82.4250  27.9133  None
# Clearwater Beach, FL                    -82.8317  27.9783  None
# Cedar Key, FL                           -83.0309  29.1336  None
# Apalachicola, FL                        -84.9806  29.7244  None
# Panama City, FL                         -85.6669  30.1523  None
# Panama City Beach, FL                   -85.8783  30.2133  None
# Pensacola, FL                           -87.2112  30.4044  None
# Weeks Bay, Mobile Bay, AL               -87.8254  30.4169  None
# Dauphin Island, AL                      -88.0750  30.2500  None
# Dog River Bridge, AL                    -88.0880  30.5652  None
# East Fowl River Bridge, AL              -88.1139  30.4436  None
# Coast Guard Sector Mobile, AL           -88.0583  30.6483  None
# Mobile State Docks, AL                  -88.0396  30.7046  None
# Chickasaw Creek, AL                     -88.0736  30.7819  None
# West Fowl River Bridge, AL              -88.1586  30.3766  None
# Bayou La Batre Bridge, AL               -88.2478  30.4062  None
# Grand Bay NERR, Mississippi Sound, MS   -88.4029  30.4132  None
# Pascagoula NOAA Lab, MS                 -88.5631  30.3678  None

# %%
wind_speed, wind_speed_table = get_coops(
    start=start,
    end=end,
    sos_name='wind_speed',
    units=cf_units.Unit('m/s'),
    bbox=bbox,
)

wind_speed_table
# Out:
#                                           station_code  \
# station_name
# Lewes, DE                                      8557380
# Ocean City Inlet, MD                           8570283
# Bishops Head, MD                               8571421
# Cove Point LNG Pier, MD                        8577018
# Solomons Island, MD                            8577330
# Piney Point, MD                                8578240
# Wachapreague, VA                               8631044
# Kiptopeke, VA                                  8632200
# Rappahannock Light, VA                         8632837
# Dahlgren, VA                                   8635027
# Lewisetta, VA                                  8635750
# York River East Rear Range Light, VA           8637611
# Yorktown USCG Training Center, VA              8637689
# Dominion Terminal Associates, VA               8638511
# South Craney Island, VA                        8638595
# Willoughby Degaussing Station, VA              8638614
# CBBT, Chesapeake Channel, VA                   8638901
# Cape Henry, VA                                 8638999
# Money Point, VA                                8639348
# Duck, NC                                       8651370
# Oregon Inlet Marina, NC                        8652587
# USCG Station Hatteras, NC                      8654467
# Beaufort, Duke Marine Lab, NC                  8656483
# Wrightsville Beach, NC                         8658163
# Charleston, Cooper River Entrance, SC          8665530
# Fort Pulaski, GA                               8670870
# Fernandina Beach, FL                           8720030
# Mayport (Bar Pilots Dock), FL                  8720218
# Blount Island Command, FL                      8720233
# Trident Pier, Port Canaveral, FL               8721604
# Lake Worth Pier, Atlantic Ocean, FL            8722670
# South Port Everglades, FL                      8722956
# Virginia Key, Biscayne Bay, FL                 8723214
# Vaca Key, Florida Bay, FL                      8723970
# Key West, FL                                   8724580
# Fort Myers, Caloosahatchee River, FL           8725520
# Middle Tampa Bay, FL                           8726412
# St. Petersburg, Tampa Bay, FL                  8726520
# Old Port Tampa, FL                             8726607
# TPA Cruise Terminal 2, FL                      8726694
# Clearwater Beach, FL                           8726724
# Cedar Key, FL                                  8727520
# Apalachicola, FL                               8728690
# Panama City, FL                                8729108
# Panama City Beach, FL                          8729210
# Pensacola, FL                                  8729840
# Fort Morgan, AL                                8734673
# Dauphin Island, AL                             8735180
# Coast Guard Sector Mobile, AL                  8736897
# Petit Bois Island, Port of Pascagoula, MS      8741003
#
#                                                                                sensor  \
# station_name
# Lewes, DE                                  urn:ioos:sensor:NOAA.NOS.CO-OPS:8557380:C1
# Ocean City Inlet, MD                       urn:ioos:sensor:NOAA.NOS.CO-OPS:8570283:C1
# Bishops Head, MD                           urn:ioos:sensor:NOAA.NOS.CO-OPS:8571421:C1
# Cove Point LNG Pier, MD                    urn:ioos:sensor:NOAA.NOS.CO-OPS:8577018:C1
# Solomons Island, MD                        urn:ioos:sensor:NOAA.NOS.CO-OPS:8577330:C1
# Piney Point, MD                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8578240:C1
# Wachapreague, VA                           urn:ioos:sensor:NOAA.NOS.CO-OPS:8631044:C1
# Kiptopeke, VA                              urn:ioos:sensor:NOAA.NOS.CO-OPS:8632200:C1
# Rappahannock Light, VA                     urn:ioos:sensor:NOAA.NOS.CO-OPS:8632837:C1
# Dahlgren, VA                               urn:ioos:sensor:NOAA.NOS.CO-OPS:8635027:C1
# Lewisetta, VA                              urn:ioos:sensor:NOAA.NOS.CO-OPS:8635750:C1
# York River East Rear Range Light, VA       urn:ioos:sensor:NOAA.NOS.CO-OPS:8637611:C1
# Yorktown USCG Training Center, VA          urn:ioos:sensor:NOAA.NOS.CO-OPS:8637689:C1
# Dominion Terminal Associates, VA           urn:ioos:sensor:NOAA.NOS.CO-OPS:8638511:C1
# South Craney Island, VA                    urn:ioos:sensor:NOAA.NOS.CO-OPS:8638595:C1
# Willoughby Degaussing Station, VA          urn:ioos:sensor:NOAA.NOS.CO-OPS:8638614:C1
# CBBT, Chesapeake Channel, VA               urn:ioos:sensor:NOAA.NOS.CO-OPS:8638901:C1
# Cape Henry, VA                             urn:ioos:sensor:NOAA.NOS.CO-OPS:8638999:C1
# Money Point, VA                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8639348:C1
# Duck, NC                                   urn:ioos:sensor:NOAA.NOS.CO-OPS:8651370:C1
# Oregon Inlet Marina, NC                    urn:ioos:sensor:NOAA.NOS.CO-OPS:8652587:C1
# USCG Station Hatteras, NC                  urn:ioos:sensor:NOAA.NOS.CO-OPS:8654467:C1
# Beaufort, Duke Marine Lab, NC              urn:ioos:sensor:NOAA.NOS.CO-OPS:8656483:C1
# Wrightsville Beach, NC                     urn:ioos:sensor:NOAA.NOS.CO-OPS:8658163:C1
# Charleston, Cooper River Entrance, SC      urn:ioos:sensor:NOAA.NOS.CO-OPS:8665530:C1
# Fort Pulaski, GA                           urn:ioos:sensor:NOAA.NOS.CO-OPS:8670870:C1
# Fernandina Beach, FL                       urn:ioos:sensor:NOAA.NOS.CO-OPS:8720030:C1
# Mayport (Bar Pilots Dock), FL              urn:ioos:sensor:NOAA.NOS.CO-OPS:8720218:C1
# Blount Island Command, FL                  urn:ioos:sensor:NOAA.NOS.CO-OPS:8720233:C1
# Trident Pier, Port Canaveral, FL           urn:ioos:sensor:NOAA.NOS.CO-OPS:8721604:C1
# Lake Worth Pier, Atlantic Ocean, FL        urn:ioos:sensor:NOAA.NOS.CO-OPS:8722670:C1
# South Port Everglades, FL                  urn:ioos:sensor:NOAA.NOS.CO-OPS:8722956:C1
# Virginia Key, Biscayne Bay, FL             urn:ioos:sensor:NOAA.NOS.CO-OPS:8723214:C1
# Vaca Key, Florida Bay, FL                  urn:ioos:sensor:NOAA.NOS.CO-OPS:8723970:C1
# Key West, FL                               urn:ioos:sensor:NOAA.NOS.CO-OPS:8724580:C1
# Fort Myers, Caloosahatchee River, FL       urn:ioos:sensor:NOAA.NOS.CO-OPS:8725520:C1
# Middle Tampa Bay, FL                       urn:ioos:sensor:NOAA.NOS.CO-OPS:8726412:C1
# St. Petersburg, Tampa Bay, FL              urn:ioos:sensor:NOAA.NOS.CO-OPS:8726520:C1
# Old Port Tampa, FL                         urn:ioos:sensor:NOAA.NOS.CO-OPS:8726607:C1
# TPA Cruise Terminal 2, FL                  urn:ioos:sensor:NOAA.NOS.CO-OPS:8726694:C1
# Clearwater Beach, FL                       urn:ioos:sensor:NOAA.NOS.CO-OPS:8726724:C1
# Cedar Key, FL                              urn:ioos:sensor:NOAA.NOS.CO-OPS:8727520:C1
# Apalachicola, FL                           urn:ioos:sensor:NOAA.NOS.CO-OPS:8728690:C1
# Panama City, FL                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8729108:C1
# Panama City Beach, FL                      urn:ioos:sensor:NOAA.NOS.CO-OPS:8729210:C1
# Pensacola, FL                              urn:ioos:sensor:NOAA.NOS.CO-OPS:8729840:C1
# Fort Morgan, AL                            urn:ioos:sensor:NOAA.NOS.CO-OPS:8734673:C1
# Dauphin Island, AL                         urn:ioos:sensor:NOAA.NOS.CO-OPS:8735180:C1
# Coast Guard Sector Mobile, AL              urn:ioos:sensor:NOAA.NOS.CO-OPS:8736897:C1
# Petit Bois Island, Port of Pascagoula, MS  urn:ioos:sensor:NOAA.NOS.CO-OPS:8741003:C1
#
#                                                lon      lat depth
# station_name
# Lewes, DE                                 -75.1192  38.7828  None
# Ocean City Inlet, MD                      -75.0917  38.3283  None
# Bishops Head, MD                          -76.0387  38.2204  None
# Cove Point LNG Pier, MD                   -76.3855  38.4044  None
# Solomons Island, MD                       -76.4508  38.3172  None
# Piney Point, MD                           -76.5333  38.1333  None
# Wachapreague, VA                          -75.6858  37.6078  None
# Kiptopeke, VA                             -75.9884  37.1652  None
# Rappahannock Light, VA                    -76.0150  37.5383  None
# Dahlgren, VA                              -77.0366  38.3197  None
# Lewisetta, VA                             -76.4646  37.9954  None
# York River East Rear Range Light, VA      -76.3333  37.2500  None
# Yorktown USCG Training Center, VA         -76.4788  37.2265  None
# Dominion Terminal Associates, VA          -76.4242  36.9623  None
# South Craney Island, VA                   -76.3383  36.8883  None
# Willoughby Degaussing Station, VA         -76.3217  36.9817  None
# CBBT, Chesapeake Channel, VA              -76.0833  37.0329  None
# Cape Henry, VA                            -76.0067  36.9300  None
# Money Point, VA                           -76.3017  36.7783  None
# Duck, NC                                  -75.7467  36.1833  None
# Oregon Inlet Marina, NC                   -75.5481  35.7950  None
# USCG Station Hatteras, NC                 -75.7042  35.2086  None
# Beaufort, Duke Marine Lab, NC             -76.6700  34.7200  None
# Wrightsville Beach, NC                    -77.7867  34.2133  None
# Charleston, Cooper River Entrance, SC     -79.9236  32.7808  None
# Fort Pulaski, GA                          -80.9017  32.0367  None
# Fernandina Beach, FL                      -81.4658  30.6714  None
# Mayport (Bar Pilots Dock), FL             -81.4279  30.3982  None
# Blount Island Command, FL                 -81.5225  30.3926  None
# Trident Pier, Port Canaveral, FL          -80.5931  28.4158  None
# Lake Worth Pier, Atlantic Ocean, FL       -80.0342  26.6128  None
# South Port Everglades, FL                 -80.1167  26.0817  None
# Virginia Key, Biscayne Bay, FL            -80.1618  25.7314  None
# Vaca Key, Florida Bay, FL                 -81.1065  24.7110  None
# Key West, FL                              -81.8078  24.5558  None
# Fort Myers, Caloosahatchee River, FL      -81.8712  26.6477  None
# Middle Tampa Bay, FL                      -82.5995  27.6618  None
# St. Petersburg, Tampa Bay, FL             -82.6269  27.7606  None
# Old Port Tampa, FL                        -82.5528  27.8578  None
# TPA Cruise Terminal 2, FL                 -82.4333  27.9333  None
# Clearwater Beach, FL                      -82.8317  27.9783  None
# Cedar Key, FL                             -83.0309  29.1336  None
# Apalachicola, FL                          -84.9817  29.7267  None
# Panama City, FL                           -85.6669  30.1523  None
# Panama City Beach, FL                     -85.8783  30.2133  None
# Pensacola, FL                             -87.2112  30.4044  None
# Fort Morgan, AL                           -88.0250  30.2283  None
# Dauphin Island, AL                        -88.0750  30.2500  None
# Coast Guard Sector Mobile, AL             -88.0583  30.6483  None
# Petit Bois Island, Port of Pascagoula, MS -88.5000  30.2133  None

# %% [markdown]
# For simplicity we will use only the stations that have both wind speed and sea surface height and reject those that have only one or the other.

# %%
common = set(ssh_table['station_code']).intersection(wind_speed_table['station_code'])

# %%
ssh_obs, win_obs = [], []
for station in common:
    ssh_obs.extend([obs for obs in ssh if obs._metadata['station_code'] == station])
    win_obs.extend([obs for obs in wind_speed if obs._metadata['station_code'] == station])

# %%
index = pd.date_range(
    start=start.replace(tzinfo=None),
    end=end.replace(tzinfo=None),
    freq='15min'
)

# Re-index and rename series.
ssh_observations = []
for series in ssh_obs:
    _metadata = series._metadata
    obs = series.reindex(index=index, limit=1, method='nearest')
    obs._metadata = _metadata
    obs.name = _metadata['station_name']
    ssh_observations.append(obs)

winds_observations = []
for series in win_obs:
    _metadata = series._metadata
    obs = series.reindex(index=index, limit=1, method='nearest')
    obs._metadata = _metadata
    obs.name = _metadata['station_name']
    winds_observations.append(obs)

# %% [markdown]
# Let's take a look at some stations to see if the data is OK. Below we have a station in Naples, FL along the Gulf of Mexico.

# %% [markdown]
# We can observe the sea level retreating around 10-Sep 9:00 and then a significant surge after 19:00.
# The lower winds at beginning of the surge is probably the eye of the hurricane.
#
# For our interactive map we will use [`bokeh`](https://bokeh.pydata.org/en/latest) HTML plots instead of the usual raster [`matplotlib`](https://matplotlib.org) ones to enhance the user experience when exploring the graphs.

# %%
from bokeh.resources import CDN
from bokeh.plotting import figure
from bokeh.embed import file_html
from bokeh.models import Range1d, LinearAxis, HoverTool

from folium import IFrame

# Plot defaults.
tools = "pan,box_zoom,reset"
width, height = 750, 250


def make_plot(ssh, wind):
    p = figure(toolbar_location='above',
               x_axis_type='datetime',
               width=width,
               height=height,
               tools=tools,
               title=ssh.name)

    p.yaxis.axis_label = 'wind speed (m/s)'

    l0 = p.line(
        x=wind.index,
        y=wind.values,
        line_width=5,
        line_cap='round',
        line_join='round',
        legend='wind speed (m/s)',
        color='#9900cc',
        alpha=0.5,
    )

    p.extra_y_ranges = {}
    p.extra_y_ranges['y2'] = Range1d(
        start=-1,
        end=3.5
    )

    p.add_layout(
        LinearAxis(
            y_range_name='y2',
            axis_label='ssh (m)'),
        'right'
    )

    l1 = p.line(
        x=ssh.index,
        y=ssh.values,
        line_width=5,
        line_cap='round',
        line_join='round',
        legend='ssh (m)',
        color='#0000ff',
        alpha=0.5,
        y_range_name='y2',
    )

    p.legend.location = 'top_left'

    p.add_tools(
        HoverTool(
            tooltips=[
                ('wind speed (m/s)', '@y'),
            ],
            renderers=[l0],
        ),
        HoverTool(
            tooltips=[
                ('ssh (m)', '@y'),
            ],
            renderers=[l1],
        ),
    )
    return p


def make_marker(p, location, fname):
    html = file_html(p, CDN, fname)
    iframe = IFrame(html, width=width+45, height=height+80)

    popup = folium.Popup(iframe, max_width=2650)
    icon = folium.Icon(color='green', icon='stats')
    marker = folium.Marker(location=location,
                           popup=popup,
                           icon=icon)
    return marker

# %% [markdown]
# Here is the final result. Explore the map by clicking on the map features plotted!

# %%
import folium
from folium.plugins import Fullscreen, MarkerCluster
from ioos_tools.ioos import get_coordinates


lon = track.centroid.x
lat = track.centroid.y

m = folium.Map(location=[lat, lon], tiles='OpenStreetMap', zoom_start=4)

Fullscreen(position='topright', force_separate_button=True).add_to(m)

marker_cluster0 = MarkerCluster(name='Observations')
marker_cluster0.add_to(m);

# %%
url = 'http://oos.soest.hawaii.edu/thredds/wms/hioos/satellite/dhw_5km'
w0 = folium.WmsTileLayer(
    url,
    name='Sea Surface Temperature',
    fmt='image/png',
    layers='CRW_SST',
    attr='PacIOOS TDS',
    overlay=True,
    transparent=True)

url = 'http://hfrnet.ucsd.edu/thredds/wms/HFRNet/USEGC/6km/hourly/RTV'
w1 = folium.WmsTileLayer(
    url,
    name='HF Radar',
    fmt='image/png',
    layers='surface_sea_water_velocity',
    attr='HFRNet',
    overlay=True,
    transparent=True)

w0.add_to(m)
w1.add_to(m);

# %%
colors = {
    'EX': 'yellow',
    'TD': 'yellow',
    'TS': 'orange',
    'HU': 'red',
}

# %%
def style_function(feature):
    return {
        'fillOpacity': 0,
        'color': 'black',
        'stroke': 1,
        'weight': 0.5,
        'opacity': 0.2,
    }


for date, row in pts.iterrows():
    storm_type = row['STORMTYPE']
    location = row['LAT'], row['LON']
    popup = '{}<br>{}'.format(date, storm_type)
    folium.CircleMarker(
        location=location,
        radius=10,
        fill=True,
        color=colors[storm_type],
        popup=popup,
    ).add_to(m)

# %%
# Observations.
for ssh, wind in zip(ssh_observations, winds_observations):
    fname = ssh._metadata['station_code']
    location = ssh._metadata['lat'], ssh._metadata['lon']
    p = make_plot(ssh, wind)
    marker = make_marker(p, location=location, fname=fname)
    marker.add_to(marker_cluster0)

folium.LayerControl().add_to(m)

p = folium.PolyLine(get_coordinates(bbox),
                    color='#009933',
                    weight=1,
                    opacity=0.2)

p.add_to(m);

# %%
def embed_map(m):
    from IPython.display import HTML

    m.save('index.html')
    with open('index.html') as f:
        html = f.read()

    iframe = '<iframe srcdoc="{srcdoc}" style="width: 100%; height: 750px; border: none"></iframe>'
    srcdoc = html.replace('"', '&quot;')
    return HTML(iframe.format(srcdoc=srcdoc))


embed_map(m)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#     <script>L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;</script>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.2.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/>
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#
#     <style>#map_7db79d7e2ae94575afe94a86a3854f2c {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     </style>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/>
# </head>
# <body>
#
#     <div class=&quot;folium-map&quot; id=&quot;map_7db79d7e2ae94575afe94a86a3854f2c&quot; ></div>
# </body>
# <script>
#
#
#         var bounds = null;
#
#
#     var map_7db79d7e2ae94575afe94a86a3854f2c = L.map(
#         'map_7db79d7e2ae94575afe94a86a3854f2c', {
#         center: [29.224708376179812, -83.30823951263632],
#         zoom: 4,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_5176fda380304d668dd4c3055c9f399c = L.tileLayer(
#         'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png',
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;subdomains&quot;: &quot;abc&quot;
# }).addTo(map_7db79d7e2ae94575afe94a86a3854f2c);
#
#             L.control.fullscreen({
#                 position: 'topright',
#                 title: 'Full Screen',
#                 titleCancel: 'Exit Full Screen',
#                 forceSeparateButton: true,
#                 }).addTo(map_7db79d7e2ae94575afe94a86a3854f2c);
#             map_7db79d7e2ae94575afe94a86a3854f2c.on('enterFullscreen', function(){
#                 console.log('entered fullscreen');
#             });
#
#
#
#             var marker_cluster_c343667d59494fa694880618f93d01c0 = L.markerClusterGroup({});
#             map_7db79d7e2ae94575afe94a86a3854f2c.addLayer(marker_cluster_c343667d59494fa694880618f93d01c0);
#
#
#         var marker_e0acc7264e684183b3aa9b17184ff924 = L.marker(
#             [37.6078, -75.6858],
#             {
#                 icon: new L.Icon.Default()
#                 }
#             ).addTo(marker_cluster_c343667d59494fa694880618f93d01c0);
#
#
#
#                 var icon_5454235f4c954a17a9118b52f9e82dec = L.AwesomeMarkers.icon({
#                     icon: 'stats',
#                     iconColor: 'white',
#                     markerColor: 'green',
#                     prefix: 'glyphicon',
#                     extraClasses: 'fa-rotate-0'
#                     });
#                 marker_e0acc7264e684183b3aa9b17184ff924.setIcon(icon_5454235f4c954a17a9118b52f9e82dec);
#
#
#             var popup_b6437738d70e4fd3a173103de163ec8e = L.popup({maxWidth: '2650'
#
#             });
#
#
#                 var i_frame_805d1a03d3da4d1a8f4bc883fe577fe4 = $('<iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;795&quot; style=&quot;border:none !important;&quot; height=&quot;330&quot;></iframe>')[0];
#                 popup_b6437738d70e4fd3a173103de163ec8e.setContent(i_frame_805d1a03d3da4d1a8f4bc883fe577fe4);
#
#
#             marker_e0acc7264e684183b3aa9b17184ff924.bindPopup(popup_b6437738d70e4fd3a173103de163ec8e)
#             ;
#
#
#
#
#         var marker_9e4e0732125b4f2b96c6ee3a971ca425 = L.marker(
#             [35.795, -75.5481],
#             {
#                 icon: new L.Icon.Default()
#                 }
#             ).addTo(marker_cluster_c343667d59494fa694880618f93d01c0);
#
#
#
#                 var icon_f5d9a957303643888e2a049264dbdeaa = L.AwesomeMarkers.icon({
#                     icon: 'stats',
#                     iconColor: 'white',
#                     markerColor: 'green',
#                     prefix: 'glyphicon',
#                     extraClasses: 'fa-rotate-0'
#                     });
#                 marker_9e4e0732125b4f2b96c6ee3a971ca425.setIcon(icon_f5d9a957303643888e2a049264dbdeaa);
#
#
#             var popup_9595d48e662441ce98124a2864694146 = L.popup({maxWidth: '2650'
#
#             });
#
#
#                 var i_frame_dccb0a3509e24a4080051dd213c58db5 = $('<iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;795&quot; style=&quot;border:none !important;&quot; height=&quot;330&quot;></iframe>')[0];
#                 popup_9595d48e662441ce98124a2864694146.setContent(i_frame_dccb0a3509e24a4080051dd213c58db5);
#
#
#             marker_9e4e0732125b4f2b96c6ee3a971ca425.bindPopup(popup_9595d48e662441ce98124a2864694146)
#             ;
#
#
#
#
#         var marker_d349f0d93c5545388c7402a8d7dbd9c6 = L.marker(
#             [38.2204, -76.0387],
#             {
#                 icon: new L.Icon.Default()
#                 }
#             ).addTo(marker_cluster_c343667d59494fa694880618f93d01c0);
#
#
#
#                 var icon_136db6a119f3405f850b60c813b6d430 = L.AwesomeMarkers.icon({
#                     icon: 'stats',
#                     iconColor: 'white',
#                     markerColor: 'green',
#                     prefix: 'glyphicon',
#                     extraClasses: 'fa-rotate-0'
#                     });
#                 marker_d349f0d93c5545388c7402a8d7dbd9c6.setIcon(icon_136db6a119f3405f850b60c813b6d430);
#
#
#             var popup_eabc78240d4440ae9d63b819cad85f83 = L.popup({maxWidth: '2650'
#
#             });
#
#
#                 var i_frame_6d49f008f4e34864a10ca4b91ef9857e = $('<iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;795&quot; style=&quot;border:none !important;&quot; height=&quot;330&quot;></iframe>')[0];
#                 popup_eabc78240d4440ae9d63b819cad85f83.setContent(i_frame_6d49f008f4e34864a10ca4b91ef9857e);
#
#
#             marker_d349f0d93c5545388c7402a8
